# %%
import time
import argparse
import pickle
import os
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
from tqdm.notebook import tqdm

import torch
import torch.nn as nn
import torch.nn.functional as F
from torchvision import datasets, transforms
import torch.utils.data as data_utils

DATASET_DIR = "../data"
TEST_AT_EPOCH_END = True

# %% [markdown]
# # Hyperparameters

# %%
class Args:
    experiment = "lenet"  # choices = ("lenet", "resnet", "vit")
    cuda = True
    seed = 0
    model_seed = 0
    num_workers = 0
    lr = 3e-3
    batch_size = 32
    epochs = 7

args = Args()

# %% [markdown]
# # Utils

# %% [markdown]
# ## Models

# %% [markdown]
# ### LeNet

# %%
# https://pytorch.org/tutorials/beginner/blitz/neural_networks_tutorial.html
class LeNet5(nn.Module):
    def __init__(self):
        super().__init__()
        # 1 input image channel, 6 output channels, 5x5 square convolution
        # kernel
        self.conv1 = nn.Conv2d(1, 6, 5, padding=2)  # add padding
        self.conv2 = nn.Conv2d(6, 16, 5)
        # an affine operation: y = Wx + b
        self.fc1 = nn.Linear(16 * 5 * 5, 120)  # 5*5 from image dimension
        self.fc2 = nn.Linear(120, 84)
        self.fc3 = nn.Linear(84, 10)
        self.t = 1

    def forward(self, x):
        # Max pooling over a (2, 2) window
        x = F.max_pool2d(F.relu(self.conv1(x)), (2, 2))
        # If the size is a square, you can specify with a single number
        x = F.max_pool2d(F.relu(self.conv2(x)), 2)
        x = torch.flatten(x, 1) # flatten all dimensions except the batch dimension
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# %% [markdown]
# ### ResNet9

# %%
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1), 
              nn.BatchNorm2d(out_channels), 
              nn.ReLU(inplace=True)]
    if pool: layers.append(nn.MaxPool2d(2))
    return nn.Sequential(*layers)

class ResNet9(nn.Module):
    def __init__(self, in_channels=3, num_classes=10):
        super().__init__()
        
        self.conv1 = conv_block(in_channels, 64)
        self.conv2 = conv_block(64, 128, pool=True)
        self.res1 = nn.Sequential(conv_block(128, 128), conv_block(128, 128))
        
        self.conv3 = conv_block(128, 256, pool=True)
        self.conv4 = conv_block(256, 512, pool=True)
        self.res2 = nn.Sequential(conv_block(512, 512), conv_block(512, 512))
        
        self.classifier = nn.Sequential(nn.MaxPool2d(4), 
                                        nn.Flatten(), 
                                        nn.Linear(512, num_classes))

    def forward(self, xb):
        out = self.conv1(xb)
        out = self.conv2(out)
        out = self.res1(out) + out
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.res2(out) + out
        out = self.classifier(out)
        return out

# %% [markdown]
# ### ViT

# %%
# https://github.com/lucidrains/vit-pytorch/blob/main/vit_pytorch/simple_vit.py

import torch
from torch import nn

from einops import rearrange
from einops.layers.torch import Rearrange

from math import log2

# helpers

def pair(t):
    return t if isinstance(t, tuple) else (t, t)

def posemb_sincos_2d(patches, temperature = 10000, dtype = torch.float32):
    _, h, w, dim, device, dtype = *patches.shape, patches.device, patches.dtype

    y, x = torch.meshgrid(torch.arange(h, device = device), torch.arange(w, device = device), indexing = 'ij')
    assert (dim % 4) == 0, 'feature dimension must be multiple of 4 for sincos emb'
    omega = torch.arange(dim // 4, device = device) / (dim // 4 - 1)
    omega = 1. / (temperature ** omega)

    y = y.flatten()[:, None] * omega[None, :]
    x = x.flatten()[:, None] * omega[None, :] 
    pe = torch.cat((x.sin(), x.cos(), y.sin(), y.cos()), dim = 1)
    return pe.type(dtype)

# classes

class FeedForward(nn.Module):
    def __init__(self, dim, hidden_dim):
        super().__init__()
        self.net = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, hidden_dim),
            nn.GELU(),
            nn.Linear(hidden_dim, dim),
        )
    def forward(self, x):
        return self.net(x)

class Attention(nn.Module):
    def __init__(self, dim, heads = 8, dim_head = 64):
        super().__init__()
        inner_dim = dim_head *  heads
        self.heads = heads
        self.scale = dim_head ** -0.5
        self.norm = nn.LayerNorm(dim)

        self.attend = nn.Softmax(dim = -1)

        self.to_qkv = nn.Linear(dim, inner_dim * 3, bias = False)
        self.to_out = nn.Linear(inner_dim, dim, bias = False)

    def forward(self, x):
        x = self.norm(x)
        magic_const = (self.heads / 2 * (1 + log2(self.heads))) ** (1 / 3)
        qkv = self.to_qkv(x).div(magic_const).chunk(3, dim = -1)
        q, k, v = map(lambda t: rearrange(t, 'b n (h d) -> b h n d', h = self.heads), qkv)

        dots = torch.matmul(q, k.transpose(-1, -2)) * self.scale

        attn = self.attend(dots)

        out = torch.matmul(attn, v)
        out = rearrange(out, 'b h n d -> b n (h d)')
        return self.to_out(out)

class Transformer(nn.Module):
    def __init__(self, dim, depth, heads, dim_head, mlp_dim):
        super().__init__()
        self.layers = nn.ModuleList([])
        for _ in range(depth):
            self.layers.append(nn.ModuleList([
                Attention(dim, heads = heads, dim_head = dim_head),
                FeedForward(dim, mlp_dim)
            ]))
    def forward(self, x):
        for attn, ff in self.layers:
            x = attn(x) + x
            x = ff(x) + x
        return x

class SimpleViT(nn.Module):
    def __init__(self, *, image_size, patch_size, num_classes, dim, depth, heads, mlp_dim, channels = 3, dim_head = 64):
        super().__init__()
        image_height, image_width = pair(image_size)
        patch_height, patch_width = pair(patch_size)

        assert image_height % patch_height == 0 and image_width % patch_width == 0, 'Image dimensions must be divisible by the patch size.'

        num_patches = (image_height // patch_height) * (image_width // patch_width)
        patch_dim = channels * patch_height * patch_width

        self.to_patch_embedding = nn.Sequential(
            Rearrange('b c (h p1) (w p2) -> b h w (p1 p2 c)', p1 = patch_height, p2 = patch_width),
            nn.LayerNorm(patch_dim),
            nn.Linear(patch_dim, dim),
            nn.LayerNorm(dim),
        )

        self.transformer = Transformer(dim, depth, heads, dim_head, mlp_dim)

        self.to_latent = nn.Identity()
        self.linear_head = nn.Sequential(
            nn.LayerNorm(dim),
            nn.Linear(dim, num_classes)
        )

    def forward(self, img):
        *_, h, w, dtype = *img.shape, img.dtype

        x = self.to_patch_embedding(img)
        pe = posemb_sincos_2d(x)
        x = rearrange(x, 'b ... d -> b (...) d') + pe

        x = self.transformer(x)
        x = x.mean(dim = 1)

        x = self.to_latent(x)
        return self.linear_head(x)

# %% [markdown]
# ## Params Utils

# %%
@torch.no_grad()
def get_flat_params(optimizer):
    return torch.cat([p.view(-1) for group in optimizer.param_groups for p in group['params']])


@torch.no_grad()
def get_flat_grads(optimizer):
    return torch.cat([p.grad.view(-1) for group in optimizer.param_groups for p in group['params'] if p.grad is not None])


@torch.no_grad()
def get_flat_exp_avg_sq(optimizer):
    return torch.cat([optimizer.state[p]["exp_avg_sq"].view(-1) for group in optimizer.param_groups for p in group['params'] if "exp_avg_sq" in optimizer.state[p]])


@torch.no_grad()
def set_flat_params(optimizer, flat_params):
    j = 0
    for group in optimizer.param_groups:
        for p in group['params']:
            p.data.copy_(flat_params[j:j + p.numel()].reshape_as(p).data)
            j += p.numel()


@torch.no_grad()
def set_flat_grads(optimizer, flat_grads):
    j = 0
    for group in optimizer.param_groups:
        for p in group['params']:
            if p.grad is not None:
                p.grad.data.copy_(flat_grads[j:j + p.numel()].reshape_as(p).data)
                j += p.numel()


@torch.no_grad()
def set_model_flat_params(model, flat_params):
    j = 0
    for p in model.parameters():
        p.data.copy_(flat_params[j:j + p.numel()].reshape_as(p).data)
        j += p.numel()


@torch.no_grad()
def check_sparsity(model, eps=1e-8, show_results=True):
    nonzeros = sum((p.abs() > eps).sum().item() for p in model.parameters())
    total_params = sum((p.numel() for p in model.parameters()))
    sparsity = 1 - nonzeros / total_params
    if show_results:
        print(f"Sparsity = {100 * sparsity:.2f}%")
    return sparsity

# %% [markdown]
# ## Test Utils

# %%
@torch.no_grad()
def test(model, loss_fn, test_loader, device, show_results=True, get_gradnorm=False):
    model.eval()

    def closure():
        test_loss = 0
        correct = 0
        for x, y in test_loader:
            x, y = x.to(device), y.to(device)
            y_pred = model(x)
            loss = loss_fn(y_pred, y) / len(test_loader)
            if get_gradnorm:
                loss.backward()
            test_loss += loss.item()
            # Accuracy
            pred = y_pred.max(dim=1).indices
            correct += (pred == y).sum().item()
        return test_loss, correct

    if get_gradnorm:
        closure = torch.enable_grad()(closure)
        test_loss, correct = closure()
        flat_grad = []
        for i, p in enumerate(model.parameters()):
            if p.grad is not None:
                flat_grad.append(p.grad.view(-1))
                p.grad = None
        gradnorm = torch.cat(flat_grad).pow(2).sum().sqrt().item()
    else:
        test_loss, correct = closure()
        gradnorm = 0.0

    sparsity = check_sparsity(model, show_results=False)
    acc = correct / len(test_loader.dataset)
    error = 1 - acc
    if show_results:
        print(f"\nTest set: Average loss: {test_loss:.4f}, "
              f"Accuracy: {correct}/{len(test_loader.dataset)} ({100. * acc:.0f}%), "
              f"Sparsity: {100. * sparsity:.2f}%\n")

    return test_loss, gradnorm, error, sparsity

# %% [markdown]
# ## Train Utils

# %%
def train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch,
          log_interval=50, test_interval=0.25, get_gradnorm=False):
    model.train()
    data = []
    # Add test at initial point
    if epoch == 1:
        result0 = test(model, loss_fn, test_loader, device, show_results=True, get_gradnorm=get_gradnorm)
        data.append((0.,) + result0)

    # Training loop
    for batch_idx, (x, y) in enumerate(train_loader):
        x, y = x.to(device), y.to(device)

        def closure():
            optimizer.zero_grad()
            y_pred = model(x)
            loss = loss_fn(y_pred, y)
            loss.backward()
            return loss

        loss = optimizer.step(closure)
        # Logging
        if batch_idx % log_interval == 0:
            batch_ratio = batch_idx / len(train_loader)
            sparsity = check_sparsity(model, show_results=False)
            print(f"Train Epoch: {epoch} [{batch_idx * len(x)}/{len(train_loader.dataset)} "
                  f"({100. * batch_ratio:.0f}%)]\tLoss: {loss.item():.6f},\tSparsity: {100. * sparsity:.2f}%")
        # Testing
        should_test = (batch_idx + 1) % round(test_interval * len(train_loader)) == 0
        last_epoch = batch_idx == len(train_loader) - 1
        if should_test or last_epoch:
            ep = epoch - 1 + (batch_idx + 1) / len(train_loader)
            result = test(model, loss_fn, test_loader, device, show_results=True, get_gradnorm=get_gradnorm)
            data.append((ep,) + result)

    return data

# %% [markdown]
# ## Optimizer Wrappers

# %% [markdown]
# ### DecoupledDecay Wrapper

# %%
class DecoupledDecay(torch.optim.Optimizer):
    def __init__(self, params, decay_type=None, decay_rate=1e-3, decay_threshold=2e-4, **kwargs):
        super().__init__(params, **kwargs)
        self.decay_type = decay_type
        self.decay_rate = decay_rate
        self.decay_threshold = decay_threshold
        self.decay = {}

    def __repr__(self):
        return "Decayed." + super().__repr__()

    def _store_decay(self):
        if self.decay_type is None:
            return

        for group in self.param_groups:
            for p in group['params']:
                if self.decay_type == "l1":
                    decay = torch.sign(p).clone()

                elif self.decay_type == "hinge":
                    if "exp_avg_sq" in self.state[p]:
                        scale = self.state[p]["exp_avg_sq"].add(1e-8).pow(-0.5)
                    else:
                        scale = torch.ones_like(p)
                    if self.decay_threshold >= 0:
                        decay_region = p.abs() > self.decay_threshold * scale
                    else:
                        decay_region = p.abs() < -self.decay_threshold * scale
                    decay = torch.zeros_like(p)
                    decay[decay_region] = torch.sign(p[decay_region]).clone()

                elif self.decay_type == "l2":
                    decay = p.clone()

                elif self.decay_type == "test":
                    if "old_p" in self.state[p] and self.state[p]["old_p"] is not None:
                        decay = self.state[p]["old_p"].sign() + (p - self.state[p]["old_p"])
                    else:
                        decay = p.sign()
                    decay = decay.clone()

                else:
                    decay = None

                # store decay
                self.decay[p] = decay

    def _apply_decay(self):
        for group in self.param_groups:
            for p in group['params']:
                if self.decay[p] is not None:
                    # XXX: decay proportional to sqrt(v) + 0.1?
                    eps = 1e-1
                    bias_correction2 = 1 - group["betas"][1] ** self.state[p]["step"]
                    vsqrt = self.state[p]["exp_avg_sq"].div(bias_correction2).sqrt().add(eps)
                    p.sub_(self.decay[p] * vsqrt, alpha=group['lr'] * self.decay_rate)
                    self.decay[p] = None

    @torch.no_grad()
    def step(self, closure):
        self._store_decay()
        loss = super().step(closure)
        self._apply_decay()

        return loss

# %% [markdown]
# ### Masked Optimizer Wrapper

# %%
class MaskedOptimizer(torch.optim.Optimizer):
    def __init__(self, *args, prune_threshold=1e-8, **kwargs):
        super().__init__(*args, **kwargs)
        self.mask = {}
        self.prune_threshold = prune_threshold
        self.use_masked_closure = False  # TODO

    def __repr__(self):
        return "Masked." + super().__repr__()

    def _parameters(self):
        for group in self.param_groups:
            for param in group['params']:
                yield param

    @torch.no_grad()
    def update_mask(self):
        for p in self._parameters():
            if p in self.mask:
                self.mask[p] &= p != 0.
            else:
                self.mask[p] = p != 0.

    @torch.no_grad()
    def mask_params(self):
        for p in self._parameters():
            if p in self.mask:
                p[~self.mask[p]] = 0.
                # XXX: mask out moments?
                if "exp_avg" in self.state[p]:
                    self.state[p]["exp_avg"][~self.mask[p]] = 0.
                if "exp_avg_sq" in self.state[p]:
                    self.state[p]["exp_avg_sq"][~self.mask[p]] = 0.

    @torch.no_grad()
    def mask_grads(self):
        for p in self._parameters():
            if p in self.mask[p] and p.grad is not None:
                p.grad.mul_(self.mask[p])

    @torch.no_grad()
    def prune_smallest(self, sparsity=0.9):
        flat_params = get_flat_params(self)
        sparse_elems = max(1, round((1 - sparsity) * flat_params.numel()))
        threshold = torch.topk(flat_params.abs().cpu(), k=sparse_elems).values[-1]
        flat_params[flat_params.abs() < threshold] = 0.
        set_flat_params(self, flat_params)
        self.update_mask()

    @torch.no_grad()
    def prune_smaller_than(self, threshold=None):
        for p in self._parameters():
            threshold = self.prune_threshold
            # XXX: prune absolutely or prop to sqrt(v)?
            # if "exp_avg_sq" in self.state[p]:
            #     threshold += self.state[p]["exp_avg_sq"].sqrt()
            p[p.abs() < threshold] = 0.
        self.update_mask()

    @torch.no_grad()
    def masked_closure(self, closure):
        closure = torch.enable_grad()(closure)

        def closure_then_mask_grads():
            closure()
            self.mask_grads()

        return closure_then_mask_grads

    def step(self, closure):
        if self.use_masked_closure:
            closure = self.masked_closure(closure)
        loss = super().step(closure)  # assuming first-order step
        self.prune_smaller_than()
        self.mask_params()
        return loss


# @torch.no_grad()
# def g2_prune_smaller_than(optimizer, threshold):
#     flat_params = get_flat_params(optimizer)
#     flat_exp_avg_sq = torch.cat([optimizer.state[p]["exp_avg_sq"].view(-1)
#                                  for group in optimizer.param_groups for p in group['params'] if "exp_avg_sq" in optimizer.state[p]])
#     flat_params[flat_exp_avg_sq.abs() < threshold] = 0.
#     set_flat_params(optimizer, flat_params)
#     return flat_params


# @torch.no_grad()
# def g2_prune_bigger_than(optimizer, threshold):
#     flat_params = get_flat_params(optimizer)
#     flat_exp_avg_sq = torch.cat([optimizer.state[p]["exp_avg_sq"].view(-1)
#                                  for group in optimizer.param_groups for p in group['params'] if "exp_avg_sq" in optimizer.state[p]])
#     flat_params[flat_exp_avg_sq.abs() > threshold] = 0.
#     set_flat_params(optimizer, flat_params)
#     return flat_params

# %%
aaa = torch.rand(2,2,2)
aaa.view(-1)[aaa.argmax()] = float('inf')
aaa
# Out:
# tensor([[[0.3696,    inf],
#          [0.8589, 0.7147]],
#
#         [[0.9569, 0.2805],
#          [0.2889, 0.8202]]])

# %% [markdown]
# ### SAM Wrapper

# %%
class SAMBase(torch.optim.Optimizer):
    def __init__(self, params, rho=0.05, scaled_max='gradnorm', sam_ord=2, **kwargs):
        assert rho >= 0.0, f"Invalid rho, should be non-negative: {rho}"
        self.adam_initialized = False
        self.sam_ord = sam_ord
        self.scaled_max = scaled_max
        self.sharpness = []
        super().__init__(params, **kwargs)
        for group in self.param_groups:
            group.setdefault("rho", rho)

    def __repr__(self):
        return "SharpnessAware." + super().__repr__()

    def _init_adam(self):
        for group in self.param_groups:
            for p in group["params"]:
                p.grad = torch.zeros_like(p)
        super().step()  # dummy step
        self.adam_initialized = True

    def _grad_norm(self):
        # put everything on the same device, in case of model parallelism
        shared_device = self.param_groups[0]["params"][0].device
        gradnorm = torch.stack([
            p.grad.pow(2).sum().to(shared_device)
            for group in self.param_groups for p in group["params"] if p.grad is not None
        ]).sum().sqrt()
        return gradnorm

    @torch.no_grad()
    def _find_approx_constrained_max(self, eps=1e-8):
        if self.scaled_max == "gradnorm":
            grad_norm = self._grad_norm()

        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None:
                    self.state[p]["old_p"] = None
                    continue

                # store old parameters
                self.state[p]["old_p"] = p.data.clone()

                # how to scale max step
                if self.scaled_max == "none":
                    denom = torch.ones(1)
                    g = p.grad
                elif self.scaled_max == "adam" and "exp_avg_sq" in self.state[p]:
                    bias_correction1 = 1 - group["betas"][0] ** self.state[p]["step"]
                    bias_correction2 = 1 - group["betas"][1] ** self.state[p]["step"]
                    denom = self.state[p]["exp_avg_sq"].div(bias_correction2).sqrt().add(0.1)
                    # g = self.state[p]["exp_avg"].div(bias_correction1)
                    g = p.grad
                elif self.scaled_max == "gradnorm":
                    denom = grad_norm.add(eps).to(p)
                    g = p.grad

                else:
                    raise NotImplementedError(self.scaled_max)

                # adjust based on ord p (as in ||e||p <= 1)
                if self.sam_ord == 1:
                    denom = torch.ones_like(g)
                    g_size = g.size()
                    g_flat = g.flatten(1)
                    i_max = g_flat.argmax(1)
                    sign_max = g_flat[:, i_max].sign()
                    g_flat.zero_()
                    g_flat[:, i_max] = sign_max
                    g = g_flat.view(g_size)
                elif self.sam_ord == 'inf':
                    denom = torch.ones_like(g)
                    g = g.sign()
                else:
                    pass

                # do step
                p.addcdiv_(g, denom, value=group["lr"] * group["rho"])
                p.grad = None

    @torch.no_grad()
    def step(self, closure=None):
        assert closure is not None, "Sharpness Aware Minimization requires closure, but it was not provided"
        closure = torch.enable_grad()(closure)
        if not self.adam_initialized:
            self._init_adam()

        loss = closure()
        self._find_approx_constrained_max()
        # XXX: decay after max step?
        if isinstance(self, DecoupledDecay):
            self._store_decay()
        loss_max = closure()  # get grad at approx max of inner problem (|e|| <= rho)
        self.sharpness.append((loss_max - loss).item())
        for group in self.param_groups:
            for p in group["params"]:
                if p.grad is None or self.state[p]["old_p"] is None:
                    continue
                p.data.copy_(self.state[p]["old_p"])  # set params back to w
                self.state[p]["old_p"] = None

        super().step()  # "sharpness-aware" super()-agnostic update (closure already evaluated)

        return loss


class SAM(SAMBase, torch.optim.SGD):
    pass

class SADAM(SAMBase, torch.optim.Adam):
    pass

# %% [markdown]
# ## Experiment Utils

# %%
def make_masked_and_decayed(Optimizer):
    class MaskedDecayedOptimizer(MaskedOptimizer, DecoupledDecay, Optimizer):
        def __repr__(self):
            return Optimizer.__name__ + "." + super().__repr__()
        pass
    return MaskedDecayedOptimizer


def init_device(cuda):
    use_cuda = torch.cuda.is_available() and cuda
    use_mps = torch.backends.mps.is_available() and cuda
    device = torch.device("cuda" if use_cuda else ("mps" if use_mps else "cpu"))
    if use_cuda:
        print(f"Using CUDA")
    if use_mps:
        print(f"Using MPS")


def init_seed(seed):
    if seed is not None:
        print(f"Setting random seed to {seed}.")
        np.random.seed(seed)
        torch.manual_seed(seed)


def init_model(experiment="lenet"):
    experiment = experiment.lower()
    if experiment == "lenet":
        model = LeNet5()

    elif experiment == "resnet":
        model = ResNet9()

    elif experiment == "vit":
        model = SimpleViT(image_size=32,
                    patch_size=16,  # patch_size=8,
                    num_classes=10,  # for cifar 10 and mnist
                    dim=128,
                    depth=12,
                    heads=8,
                    mlp_dim=64)

    else:
        raise NotImplementedError(f"experiment '{experiment}' not implemented.")

    return model


@ torch.no_grad()
def count_params(model):
    return sum(p.numel() for p in model.parameters())


def load_dataset(experiment="lenet"):
    experiment = experiment.lower()
    if experiment == "lenet":
        transform = transforms.Compose([
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,))
        ])
        train_dataset = datasets.MNIST(DATASET_DIR, train=True, download=True, transform=transform)
        test_dataset = datasets.MNIST(DATASET_DIR, train=False, transform=transform)

    elif experiment in ("resnet", "vit"):
        ### MNIST ###
        image_size = 32
        transform = transforms.Compose([
            transforms.Grayscale(3),
            transforms.Resize(image_size),
            transforms.ToTensor(),
            transforms.Normalize((0.5,), (0.5,)),
        ])
        train_dataset = datasets.MNIST(DATASET_DIR, train=True, download=True, transform=transform)
        test_dataset = datasets.MNIST(DATASET_DIR, train=False, transform=transform)
        ### CIFAR-10 ###
        # cifar_mean = (0.4914, 0.4822, 0.4465)
        # cifar_std = (0.2023, 0.1994, 0.2010)
        # train_transform = transforms.Compose([
        #     transforms.RandomCrop(image_size, padding=4),
        #     transforms.RandomHorizontalFlip(),
        #     transforms.ToTensor(),
        #     transforms.Normalize(cifar_mean, cifar_std)
        # ])
        # test_transform = transforms.Compose([
        #     transforms.ToTensor(),
        #     transforms.Normalize(cifar10_mean, cifar10_std)
        # ])
        # train_dataset = datasets.CIFAR10(DATASET_DIR, train=True, download=True, transform=train_transform)
        # test_dataset = datasets.CIFAR10(DATASET_DIR, train=False, transform=test_transform)

    else:
        raise NotImplementedError(f"experiment '{experiment}' not implemented.")


    return train_dataset, test_dataset


def init_experiment(args, Optimizer=torch.optim.SGD, **optim_args):
    device = init_device(args.cuda)
    
    # All runs start are init based on the model seed
    print(f"Initializing model with random seed {args.model_seed}.")
    init_seed(args.model_seed)
    model = init_model(args.experiment).to(device)

    # Load dataset and initialize dataloader
    init_seed(args.seed)
    train_dataset, test_dataset = load_dataset(args.experiment)
    train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=args.batch_size,
                                                shuffle=True, num_workers=args.num_workers)
    test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=args.batch_size,
                                                shuffle=False, num_workers=args.num_workers)

    # Loss and optimizer
    loss_fn = nn.CrossEntropyLoss()
    MaskedDecayedOptimizer = make_masked_and_decayed(Optimizer)
    optimizer = MaskedDecayedOptimizer(model.parameters(), **optim_args)

    print(f"Model has {count_params(model)} parameters")

    return model, optimizer, loss_fn, train_loader, test_loader, device

# %% [markdown]
# ### Test

# %%
# testing inits
args = Args()
init_experiment(args, Optimizer=torch.optim.SGD, lr=args.lr)
init_experiment(args, Optimizer=torch.optim.SGD, lr=args.lr, momentum=0.9, decay_type="l2")
init_experiment(args, Optimizer=torch.optim.Adam, lr=args.lr, betas=(0.9, 0.999))
init_experiment(args, Optimizer=SAM, lr=args.lr, momentum=0.9, rho=args.lr/2)
init_experiment(args, Optimizer=SADAM, lr=args.lr, betas=(0.9, 0.999), rho=args.lr/2)
# Out:
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters
# (LeNet5(
#    (conv1): Conv2d(1, 6, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2))
#    (conv2): Conv2d(6, 16, kernel_size=(5, 5), stride=(1, 1))
#    (fc1): Linear(in_features=400, out_features=120, bias=True)
#    (fc2): Linear(in_features=120, out_features=84, bias=True)
#    (fc3): Linear(in_features=84, out_features=10, bias=True)
#  ),
#  SADAM.Masked.Decayed.SharpnessAware.MaskedDecayedOptimizer (
#  Parameter Group 0
#      amsgrad: False
#      betas: (0.9, 0.999)
#      capturable: False
#      differentiable: False
#      eps: 1e-08
#      foreach: None
#      fused: None
#      lr: 0.003
#      maximize: False
#      rho: 0.0015
#      weight_decay: 0
#  ),
#  CrossEntropyLoss(),
#  <torch.utils.data.dataloader.DataLoader at 0x7f7a40e13c10>,
#  <torch.utils.data.dataloader.DataLoader at 0x7f7a40e11db0>,
#  None)

# %% [markdown]
# # Experiments 1

# %% [markdown]
# ## Does Sharpness Aware Minimization help find sparser solutions and better lottery tickets?

# %%
# Train
model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(
    args, Optimizer=torch.optim.SGD, lr=args.lr, momentum=0.9, decay_type="l1")

data = []
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
    # prune
    check_sparsity(model)
    optimizer.prune_smallest(sparsity=1 - 0.5**epoch)
    check_sparsity(model)
    test(model, loss_fn, test_loader, device)
    print()
# Out:
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters
#
# Test set: Average loss: 2.3040, Accuracy: 1009/10000 (10%), Sparsity: 0.00%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.297592,	Sparsity: 0.00%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 2.290902,	Sparsity: 0.01%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[882], line 7
#       5 data = []
#       6 for epoch in range(1, args.epochs + 1):
# ----> 7     results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
#       8     data += results
#       9     # prune
#
# Cell In[876], line 21, in train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch, log_interval, test_interval, get_gradnorm)
#      18     loss.backward()
#      19     return loss
# ---> 21 loss = optimizer.step(closure)
#      22 # Logging
#      23 if batch_idx % log_interval == 0:
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# Cell In[878], line 73, in MaskedOptimizer.step(self, closure)
#      71 if self.use_masked_closure:
#      72     closure = self.masked_closure(closure)
# ---> 73 loss = super().step(closure)  # assuming first-order step
#      74 self.prune_smaller_than()
#      75 self.mask_params()
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[877], line 58, in DecoupledDecay.step(self, closure)
#      56 @torch.no_grad()
#      57 def step(self, closure):
# ---> 58     self._store_decay()
#      59     loss = super().step(closure)
#      60     self._apply_decay()
#
# Cell In[877], line 19, in DecoupledDecay._store_decay(self)
#      17 for p in group['params']:
#      18     if self.decay_type == "l1":
# ---> 19         decay = torch.sign(p).clone()
#      21     elif self.decay_type == "hinge":
#      22         if "exp_avg_sq" in self.state[p]:
#
# KeyboardInterrupt:

# %%
# Train
model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(
    args, Optimizer=SAM, lr=args.lr, momentum=0.9, rho=args.lr/2, decay_type="l1")

data = []
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
    # prune
    check_sparsity(model)
    optimizer.prune_smallest(sparsity=1 - 0.5**epoch)
    check_sparsity(model)
    test(model, loss_fn, test_loader, device)
    print()

# %% [markdown]
# ## Test AdamW vs. DecayedAdam

# %%
# Train
model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(
    args, Optimizer=torch.optim.Adam, lr=args.lr, decay_type='l2', decay_rate=1e-2)
data = []
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results

# %%
# Train
model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(
    args, Optimizer=torch.optim.AdamW, lr=args.lr, weight_decay=1e-2)
data = []
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results

# %%
# Train
model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(
    args, Optimizer=torch.optim.Adam, lr=args.lr)
data = []
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results

# %%
# Train
model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(
    args, Optimizer=torch.optim.Adam, lr=args.lr, decay_type='l1', decay_rate=1e-2)
data = []
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
    check_sparsity(model)

# %% [markdown]
# ## Sharpness-Aware Adam with decoupled L1 decay

# %%
# Train
args.lr = 1e-2
model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(
    args, Optimizer=SADAM, lr=args.lr, rho=0.005, decay_type='l1', decay_rate=1e-3, scaled_max="adam")
sched = torch.optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.9)
data = []
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    sched.step()
    data += results

# %%
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    sched.step()
    data += results

# %%
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    sched.step()
    data += results

# %%
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    sched.step()
    data += results

# %%
for epoch in range(1, args.epochs + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    sched.step()
    data += results

# %% [markdown]
# # Experiments 2 (LeNet)

# %% [markdown]
# ## L1

# %%
args.experiment = "lenet"
args.lr = 1e-2

rho = 0.1  # relative to lr
decay_rate = 0.1  # relative to lr
prune_threshold = 2**-8
decay_type = "l1"

optim_args = dict(lr=args.lr, rho=rho, scaled_max="adam", sam_ord=1, #amsgrad=True,
                  decay_type=decay_type, decay_rate=decay_rate, prune_threshold=prune_threshold)

model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(args, Optimizer=SADAM, **optim_args)
model_state_dict0 = deepcopy(model.state_dict())
optimizer_state_dict0 = deepcopy(optimizer.state_dict())
# Out:
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters

# %%
### Reset ###
data = []
model.load_state_dict(model_state_dict0)
optimizer.load_state_dict(optimizer_state_dict0)

# %%
# %%time
for epoch in range(1, 2 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 2.3040, Accuracy: 1009/10000 (10%), Sparsity: 0.00%
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File <timed exec>:2
#
# Cell In[9], line 21, in train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch, log_interval, test_interval, get_gradnorm)
#      18     loss.backward()
#      19     return loss
# ---> 21 loss = optimizer.step(closure)
#      22 # Logging
#      23 if batch_idx % log_interval == 0:
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# Cell In[11], line 73, in MaskedOptimizer.step(self, closure)
#      71 if self.use_masked_closure:
#      72     closure = self.masked_closure(closure)
# ---> 73 loss = super().step(closure)  # assuming first-order step
#      74 self.prune_smaller_than()
#      75 self.mask_params()
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[10], line 63, in DecoupledDecay.step(self, closure)
#      60 @torch.no_grad()
#      61 def step(self, closure):
#      62     self._store_decay()
# ---> 63     loss = super().step(closure)
#      64     self._apply_decay()
#      66     return loss
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[39], line 87, in SAMBase.step(self, closure)
#      84     self._init_adam()
#      86 loss = closure()
# ---> 87 self._find_approx_constrained_max()
#      88 # XXX: decay after max step?
#      89 if isinstance(self, DecoupledDecay):
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[39], line 68, in SAMBase._find_approx_constrained_max(self, eps)
#      66     sign_max = g.view(-1)[i_max].sign()
#      67     g.zero_()
# ---> 68     g[i_max] = sign_max
#      69 elif self.sam_ord == 'inf':
#      70     denom = torch.ones_like(g)
#
# IndexError: index 97 is out of bounds for dimension 0 with size 6

# %% [markdown]
# ## L2

# %%
args.experiment = "lenet"
args.lr = 1e-2

rho = 0.1  # relative to lr
decay_rate = 0.1  # relative to lr
prune_threshold = 2**-8
decay_type = "l1"

optim_args = dict(lr=args.lr, rho=rho, scaled_max="adam", sam_ord=2, #amsgrad=True,
                  decay_type=decay_type, decay_rate=decay_rate, prune_threshold=prune_threshold)

model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(args, Optimizer=SADAM, **optim_args)
model_state_dict0 = deepcopy(model.state_dict())
optimizer_state_dict0 = deepcopy(optimizer.state_dict())
# Out:
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 61706 parameters

# %%
### Reset ###
data = []
model.load_state_dict(model_state_dict0)
optimizer.load_state_dict(optimizer_state_dict0)

# %%
# %%time
for epoch in range(1, 2 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 2.3040, Accuracy: 1009/10000 (10%), Sparsity: 0.00%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.297592,	Sparsity: 7.20%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.750621,	Sparsity: 46.36%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.377176,	Sparsity: 51.56%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.081441,	Sparsity: 54.79%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.138456,	Sparsity: 57.04%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.248873,	Sparsity: 59.22%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.166754,	Sparsity: 61.03%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.021488,	Sparsity: 62.82%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.082151,	Sparsity: 64.34%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.148280,	Sparsity: 65.63%
#
# Test set: Average loss: 0.1244, Accuracy: 9600/10000 (96%), Sparsity: 66.09%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.110322,	Sparsity: 67.11%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.101230,	Sparsity: 69.45%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.056705,	Sparsity: 71.69%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.225273,	Sparsity: 73.94%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.023454,	Sparsity: 76.37%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.047795,	Sparsity: 78.50%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.189625,	Sparsity: 80.59%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.156595,	Sparsity: 82.57%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.047791,	Sparsity: 84.33%
#
# Test set: Average loss: 0.0737, Accuracy: 9762/10000 (98%), Sparsity: 85.55%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.170083,	Sparsity: 85.99%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.074663,	Sparsity: 87.60%
# Train Epoch: 1 [33600/60000 (56%)]	Loss: 0.137300,	Sparsity: 88.45%
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.048922,	Sparsity: 88.98%
# Train Epoch: 1 [36800/60000 (61%)]	Loss: 0.284424,	Sparsity: 89.38%
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.054587,	Sparsity: 89.74%
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.083499,	Sparsity: 90.18%
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.140831,	Sparsity: 90.51%
# Train Epoch: 1 [43200/60000 (72%)]	Loss: 0.153728,	Sparsity: 90.88%
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.003268,	Sparsity: 91.15%
#
# Test set: Average loss: 0.0665, Accuracy: 9805/10000 (98%), Sparsity: 91.19%
#
# Train Epoch: 1 [46400/60000 (77%)]	Loss: 0.014131,	Sparsity: 91.43%
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.004454,	Sparsity: 91.64%
# Train Epoch: 1 [49600/60000 (83%)]	Loss: 0.033253,	Sparsity: 91.84%
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.048250,	Sparsity: 91.99%
# Train Epoch: 1 [52800/60000 (88%)]	Loss: 0.051047,	Sparsity: 92.15%
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.054839,	Sparsity: 92.30%
# Train Epoch: 1 [56000/60000 (93%)]	Loss: 0.004937,	Sparsity: 92.44%
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.024632,	Sparsity: 92.59%
# Train Epoch: 1 [59200/60000 (99%)]	Loss: 0.108306,	Sparsity: 92.74%
#
# Test set: Average loss: 0.0647, Accuracy: 9794/10000 (98%), Sparsity: 92.80%
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.035518,	Sparsity: 92.81%
# Train Epoch: 2 [1600/60000 (3%)]	Loss: 0.008589,	Sparsity: 92.93%
# Train Epoch: 2 [3200/60000 (5%)]	Loss: 0.113032,	Sparsity: 93.04%
# Train Epoch: 2 [4800/60000 (8%)]	Loss: 0.106738,	Sparsity: 93.15%
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.014603,	Sparsity: 93.27%
# Train Epoch: 2 [8000/60000 (13%)]	Loss: 0.035413,	Sparsity: 93.36%
# Train Epoch: 2 [9600/60000 (16%)]	Loss: 0.115663,	Sparsity: 93.44%
# Train Epoch: 2 [11200/60000 (19%)]	Loss: 0.163683,	Sparsity: 93.54%
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.007968,	Sparsity: 93.60%
# Train Epoch: 2 [14400/60000 (24%)]	Loss: 0.002786,	Sparsity: 93.67%
#
# Test set: Average loss: 0.0786, Accuracy: 9751/10000 (98%), Sparsity: 93.69%
#
# Train Epoch: 2 [16000/60000 (27%)]	Loss: 0.002414,	Sparsity: 93.74%
# Train Epoch: 2 [17600/60000 (29%)]	Loss: 0.049603,	Sparsity: 93.81%
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.094646,	Sparsity: 93.86%
# Train Epoch: 2 [20800/60000 (35%)]	Loss: 0.110510,	Sparsity: 93.91%
# Train Epoch: 2 [22400/60000 (37%)]	Loss: 0.032801,	Sparsity: 94.00%
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.013165,	Sparsity: 94.08%
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.009999,	Sparsity: 94.16%
# Train Epoch: 2 [27200/60000 (45%)]	Loss: 0.011517,	Sparsity: 94.22%
# Train Epoch: 2 [28800/60000 (48%)]	Loss: 0.007007,	Sparsity: 94.29%
#
# Test set: Average loss: 0.0682, Accuracy: 9790/10000 (98%), Sparsity: 94.33%
#
# Train Epoch: 2 [30400/60000 (51%)]	Loss: 0.025951,	Sparsity: 94.34%
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.006131,	Sparsity: 94.40%
# Train Epoch: 2 [33600/60000 (56%)]	Loss: 0.013823,	Sparsity: 94.45%
# Train Epoch: 2 [35200/60000 (59%)]	Loss: 0.017270,	Sparsity: 94.53%
# Train Epoch: 2 [36800/60000 (61%)]	Loss: 0.065300,	Sparsity: 94.60%
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.033916,	Sparsity: 94.67%
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.014568,	Sparsity: 94.73%
# Train Epoch: 2 [41600/60000 (69%)]	Loss: 0.043583,	Sparsity: 94.79%
# Train Epoch: 2 [43200/60000 (72%)]	Loss: 0.018625,	Sparsity: 94.85%
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.272000,	Sparsity: 94.89%
#
# Test set: Average loss: 0.0631, Accuracy: 9802/10000 (98%), Sparsity: 94.90%
#
# Train Epoch: 2 [46400/60000 (77%)]	Loss: 0.007244,	Sparsity: 94.96%
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.253132,	Sparsity: 95.02%
# Train Epoch: 2 [49600/60000 (83%)]	Loss: 0.013370,	Sparsity: 95.06%
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.037171,	Sparsity: 95.10%
# Train Epoch: 2 [52800/60000 (88%)]	Loss: 0.021367,	Sparsity: 95.14%
# Train Epoch: 2 [54400/60000 (91%)]	Loss: 0.081303,	Sparsity: 95.17%
# Train Epoch: 2 [56000/60000 (93%)]	Loss: 0.007523,	Sparsity: 95.22%
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.007840,	Sparsity: 95.26%
# Train Epoch: 2 [59200/60000 (99%)]	Loss: 0.021838,	Sparsity: 95.29%
#
# Test set: Average loss: 0.0563, Accuracy: 9839/10000 (98%), Sparsity: 95.31%
#
# CPU times: user 4min 3s, sys: 3min 42s, total: 7min 45s
# Wall time: 2min 20s

# %%
test(model, loss_fn, test_loader, device)
# Out:
# Test set: Average loss: 0.0563, Accuracy: 9839/10000 (98%), Sparsity: 95.31%
# (0.05632343794945882, 0.0, 0.016100000000000003, 0.9530839788675332)

# %%
def smoothed(arr):
    arr = np.array(arr)
    cumsum_vec = np.cumsum(np.insert(arr, 0, 0))
    window_width = len(cumsum_vec) // 100
    smoothed_arr = (cumsum_vec[window_width:] - cumsum_vec[:-window_width]) / window_width
    return smoothed_arr


@torch.no_grad()
def plot_stats(optimizer, data=None, num_dims=2):
    # p1 = torch.cat([p.view(-1) for group in optimizer.param_groups for p in group['params']]).cpu().abs()
    # g1 = torch.cat([optimizer.state[p]['exp_avg'].view(-1) for group in optimizer.param_groups for p in group['params']]).cpu().abs()
    # g2 = torch.cat([optimizer.state[p]['exp_avg_sq'].view(-1) for group in optimizer.param_groups for p in group['params']]).cpu().abs()

    if data is not None:
        plt.figure()
        plt.semilogy(np.array(data)[:,1])
        plt.title("loss")
        plt.figure()
        plt.plot(np.array(data)[:,4])
        plt.title("sparsity")

    plt.figure()
    plt.plot(smoothed(optimizer.sharpness[10:]))
    plt.plot([0, len(optimizer.sharpness)], [0.0, 0.0], color='r', linestyle='dashed')
    plt.title("sharpness")
    
    plt.figure()
    for group in optimizer.param_groups:
        for p in group['params']:
            if len(p.shape) == num_dims:
                p1 = p.cpu()
                plt.hist(p1[p1.abs() > 1e-3], bins=50, alpha=0.5)
    plt.title("params")

    plt.figure()
    for group in optimizer.param_groups:
        for p in group['params']:
            if len(p.shape) == num_dims:
                g1 = optimizer.state[p]["exp_avg"].cpu()
                plt.hist(g1[g1.abs() > 1e-4], bins=50, alpha=0.5)
    plt.title("exp_avg")

    plt.figure()
    for group in optimizer.param_groups:
        for p in group['params']:
            if len(p.shape) == num_dims:
                g2 = optimizer.state[p]["exp_avg_sq"].sqrt().cpu().abs()
                plt.hist(g2[g2 > 0].log10(), bins=50, alpha=0.5)
    plt.title("log(exp_avg_sq)")

    plt.figure()
    for group in optimizer.param_groups:
        for p in group['params']:
            if len(p.shape) == num_dims:
                pg = (p * optimizer.state[p]["exp_avg"]).cpu()
                plt.hist(pg[pg != 0], bins=50, alpha=0.5)
    plt.title("p * m")
    plt.figure()
    for group in optimizer.param_groups:
        for p in group['params']:
            if len(p.shape) == num_dims:
                pg = (p * optimizer.state[p]["exp_avg"] / optimizer.state[p]["exp_avg_sq"].sqrt().add(1e-8)).cpu()
                plt.hist(pg[pg != 0], bins=50, alpha=0.5)
    plt.title("p * m/sqrt(v)")


plot_stats(optimizer, data)

# %% [markdown]
# # Experiment 3 (ResNet)

# %%
args.experiment = "resnet"
args.lr = 1e-3

rho = 0.1  # relative to lr
decay_rate = 0.1  # relative to lr
prune_threshold = 2**-8
decay_type = "l1"

optim_args = dict(lr=args.lr, rho=rho, scaled_max="adam", sam_ord=2, #amsgrad=True,
                  decay_type=decay_type, decay_rate=decay_rate, prune_threshold=prune_threshold)

model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(args, Optimizer=SADAM, **optim_args)

data = []
model_state_dict0 = deepcopy(model.state_dict())
optimizer_state_dict0 = deepcopy(optimizer.state_dict())
# Out:
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 6575370 parameters

# %%
# %%time
### Run ###
for epoch in range(1, 1 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 2.3021, Accuracy: 1135/10000 (11%), Sparsity: 0.03%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.297697,	Sparsity: 23.78%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.709657,	Sparsity: 40.71%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.280786,	Sparsity: 44.42%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.096168,	Sparsity: 46.73%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.062881,	Sparsity: 48.76%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.147107,	Sparsity: 50.65%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.050564,	Sparsity: 52.40%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.026526,	Sparsity: 54.15%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.056467,	Sparsity: 55.88%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.141497,	Sparsity: 57.53%
#
# Test set: Average loss: 0.1210, Accuracy: 9641/10000 (96%), Sparsity: 58.15%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.033438,	Sparsity: 59.39%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.101147,	Sparsity: 61.30%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.009295,	Sparsity: 63.14%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.112317,	Sparsity: 64.84%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.040794,	Sparsity: 66.60%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.020672,	Sparsity: 68.27%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.077044,	Sparsity: 69.93%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.159557,	Sparsity: 71.58%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.071419,	Sparsity: 73.21%
#
# Test set: Average loss: 0.0382, Accuracy: 9888/10000 (99%), Sparsity: 74.38%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.103283,	Sparsity: 74.80%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.009167,	Sparsity: 76.39%
# Train Epoch: 1 [33600/60000 (56%)]	Loss: 0.024845,	Sparsity: 77.97%
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.029745,	Sparsity: 79.45%
# Train Epoch: 1 [36800/60000 (61%)]	Loss: 0.244151,	Sparsity: 80.64%
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.094044,	Sparsity: 81.75%
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.010636,	Sparsity: 82.90%
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.050003,	Sparsity: 84.01%
# Train Epoch: 1 [43200/60000 (72%)]	Loss: 0.312502,	Sparsity: 85.06%
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.008988,	Sparsity: 86.10%
#
# Test set: Average loss: 0.0318, Accuracy: 9901/10000 (99%), Sparsity: 86.22%
#
# Train Epoch: 1 [46400/60000 (77%)]	Loss: 0.002411,	Sparsity: 87.08%
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.002261,	Sparsity: 88.02%
# Train Epoch: 1 [49600/60000 (83%)]	Loss: 0.009509,	Sparsity: 88.91%
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.239413,	Sparsity: 89.74%
# Train Epoch: 1 [52800/60000 (88%)]	Loss: 0.003100,	Sparsity: 90.43%
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.007908,	Sparsity: 90.90%
# Train Epoch: 1 [56000/60000 (93%)]	Loss: 0.002040,	Sparsity: 91.33%
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.016117,	Sparsity: 91.70%
# Train Epoch: 1 [59200/60000 (99%)]	Loss: 0.101218,	Sparsity: 92.06%
#
# Test set: Average loss: 0.0246, Accuracy: 9927/10000 (99%), Sparsity: 92.22%
#
# CPU times: user 4h 8min 48s, sys: 2h 28min 21s, total: 6h 37min 9s
# Wall time: 59min 50s

# %%
# %%time
### Run ###
for epoch in range(1, 1 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 0.0246, Accuracy: 9927/10000 (99%), Sparsity: 92.22%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.014142,	Sparsity: 92.23%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.001859,	Sparsity: 92.56%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.001524,	Sparsity: 92.86%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.012334,	Sparsity: 93.15%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.004643,	Sparsity: 93.43%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.057010,	Sparsity: 93.70%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.032653,	Sparsity: 93.94%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.010581,	Sparsity: 94.18%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.227442,	Sparsity: 94.39%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.019178,	Sparsity: 94.56%
#
# Test set: Average loss: 0.0306, Accuracy: 9905/10000 (99%), Sparsity: 94.62%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.013050,	Sparsity: 94.70%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.021048,	Sparsity: 94.85%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.002132,	Sparsity: 95.00%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.086562,	Sparsity: 95.13%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.011127,	Sparsity: 95.27%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.016149,	Sparsity: 95.40%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.001791,	Sparsity: 95.51%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.240781,	Sparsity: 95.62%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.009269,	Sparsity: 95.74%
#
# Test set: Average loss: 0.0416, Accuracy: 9870/10000 (99%), Sparsity: 95.81%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.005980,	Sparsity: 95.84%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.007558,	Sparsity: 95.95%
# Train Epoch: 1 [33600/60000 (56%)]	Loss: 0.003984,	Sparsity: 96.04%
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.062071,	Sparsity: 96.13%
# Train Epoch: 1 [36800/60000 (61%)]	Loss: 0.002296,	Sparsity: 96.21%
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.002475,	Sparsity: 96.30%
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.000719,	Sparsity: 96.37%
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.001483,	Sparsity: 96.43%
# Train Epoch: 1 [43200/60000 (72%)]	Loss: 0.009742,	Sparsity: 96.49%
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.194029,	Sparsity: 96.55%
#
# Test set: Average loss: 0.0601, Accuracy: 9814/10000 (98%), Sparsity: 96.56%
#
# Train Epoch: 1 [46400/60000 (77%)]	Loss: 0.016468,	Sparsity: 96.60%
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.000988,	Sparsity: 96.65%
# Train Epoch: 1 [49600/60000 (83%)]	Loss: 0.009188,	Sparsity: 96.69%
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.015229,	Sparsity: 96.74%
# Train Epoch: 1 [52800/60000 (88%)]	Loss: 0.004876,	Sparsity: 96.77%
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.118755,	Sparsity: 96.81%
# Train Epoch: 1 [56000/60000 (93%)]	Loss: 0.027043,	Sparsity: 96.85%
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.016290,	Sparsity: 96.89%
# Train Epoch: 1 [59200/60000 (99%)]	Loss: 0.000632,	Sparsity: 96.93%
#
# Test set: Average loss: 0.0445, Accuracy: 9860/10000 (99%), Sparsity: 96.95%
#
# CPU times: user 3h 49min 47s, sys: 2h 22s, total: 5h 50min 10s
# Wall time: 53min 55s

# %%
# %%time
### Run ###
for epoch in range(1, 1 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 0.0445, Accuracy: 9860/10000 (99%), Sparsity: 96.95%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.011864,	Sparsity: 96.95%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.019166,	Sparsity: 97.00%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.002702,	Sparsity: 97.04%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.002901,	Sparsity: 97.07%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.018393,	Sparsity: 97.10%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.113251,	Sparsity: 97.13%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.000513,	Sparsity: 97.15%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.006343,	Sparsity: 97.18%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.006114,	Sparsity: 97.20%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.094562,	Sparsity: 97.24%
#
# Test set: Average loss: 0.0205, Accuracy: 9936/10000 (99%), Sparsity: 97.25%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.005244,	Sparsity: 97.27%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.003101,	Sparsity: 97.29%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.034089,	Sparsity: 97.32%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.015516,	Sparsity: 97.35%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.000554,	Sparsity: 97.37%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.058947,	Sparsity: 97.40%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.002239,	Sparsity: 97.42%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.008630,	Sparsity: 97.45%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.000832,	Sparsity: 97.47%
#
# Test set: Average loss: 0.0268, Accuracy: 9907/10000 (99%), Sparsity: 97.48%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.062959,	Sparsity: 97.49%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.000284,	Sparsity: 97.52%
# Train Epoch: 1 [33600/60000 (56%)]	Loss: 0.001200,	Sparsity: 97.54%
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.000336,	Sparsity: 97.56%
# Train Epoch: 1 [36800/60000 (61%)]	Loss: 0.026665,	Sparsity: 97.58%
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.066662,	Sparsity: 97.60%
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.015182,	Sparsity: 97.62%
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.004224,	Sparsity: 97.64%
# Train Epoch: 1 [43200/60000 (72%)]	Loss: 0.001616,	Sparsity: 97.67%
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.317563,	Sparsity: 97.68%
#
# Test set: Average loss: 0.0351, Accuracy: 9899/10000 (99%), Sparsity: 97.69%
#
# Train Epoch: 1 [46400/60000 (77%)]	Loss: 0.007114,	Sparsity: 97.71%
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.015549,	Sparsity: 97.73%
# Train Epoch: 1 [49600/60000 (83%)]	Loss: 0.000642,	Sparsity: 97.74%
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.059736,	Sparsity: 97.76%
# Train Epoch: 1 [52800/60000 (88%)]	Loss: 0.035581,	Sparsity: 97.78%
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.004419,	Sparsity: 97.79%
# Train Epoch: 1 [56000/60000 (93%)]	Loss: 0.018467,	Sparsity: 97.81%
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.002018,	Sparsity: 97.83%
# Train Epoch: 1 [59200/60000 (99%)]	Loss: 0.005008,	Sparsity: 97.84%
#
# Test set: Average loss: 0.0187, Accuracy: 9930/10000 (99%), Sparsity: 97.85%
#
# CPU times: user 3h 55min 22s, sys: 2h 12min 5s, total: 6h 7min 27s
# Wall time: 54min 46s

# %%
# %%time
### Run ###
for epoch in range(1, 2 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 0.0187, Accuracy: 9930/10000 (99%), Sparsity: 97.85%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.050620,	Sparsity: 97.85%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.000613,	Sparsity: 97.86%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.046877,	Sparsity: 97.87%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.004283,	Sparsity: 97.89%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.000794,	Sparsity: 97.90%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.000805,	Sparsity: 97.91%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.000072,	Sparsity: 97.92%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.000692,	Sparsity: 97.94%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.004880,	Sparsity: 97.95%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.001172,	Sparsity: 97.96%
#
# Test set: Average loss: 0.0146, Accuracy: 9950/10000 (100%), Sparsity: 97.96%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.074788,	Sparsity: 97.97%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.001314,	Sparsity: 97.98%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.002226,	Sparsity: 98.00%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.000996,	Sparsity: 98.01%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.000619,	Sparsity: 98.02%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.031667,	Sparsity: 98.03%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.012295,	Sparsity: 98.05%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.009745,	Sparsity: 98.06%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.012586,	Sparsity: 98.07%
#
# Test set: Average loss: 0.0277, Accuracy: 9917/10000 (99%), Sparsity: 98.08%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.000389,	Sparsity: 98.09%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.000662,	Sparsity: 98.09%
# Train Epoch: 1 [33600/60000 (56%)]	Loss: 0.004655,	Sparsity: 98.11%
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.006787,	Sparsity: 98.12%
# Train Epoch: 1 [36800/60000 (61%)]	Loss: 0.005286,	Sparsity: 98.13%
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.002733,	Sparsity: 98.14%
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.000827,	Sparsity: 98.16%
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.045662,	Sparsity: 98.17%
# Train Epoch: 1 [43200/60000 (72%)]	Loss: 0.001868,	Sparsity: 98.18%
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.002531,	Sparsity: 98.19%
#
# Test set: Average loss: 0.0267, Accuracy: 9910/10000 (99%), Sparsity: 98.19%
#
# Train Epoch: 1 [46400/60000 (77%)]	Loss: 0.001144,	Sparsity: 98.20%
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.000379,	Sparsity: 98.21%
# Train Epoch: 1 [49600/60000 (83%)]	Loss: 0.001200,	Sparsity: 98.22%
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.000416,	Sparsity: 98.23%
# Train Epoch: 1 [52800/60000 (88%)]	Loss: 0.001445,	Sparsity: 98.24%
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.040149,	Sparsity: 98.25%
# Train Epoch: 1 [56000/60000 (93%)]	Loss: 0.033486,	Sparsity: 98.26%
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.009487,	Sparsity: 98.27%
# Train Epoch: 1 [59200/60000 (99%)]	Loss: 0.007064,	Sparsity: 98.28%
#
# Test set: Average loss: 0.0227, Accuracy: 9925/10000 (99%), Sparsity: 98.28%
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.483054,	Sparsity: 98.29%
# Train Epoch: 2 [1600/60000 (3%)]	Loss: 0.003662,	Sparsity: 98.39%
# Train Epoch: 2 [3200/60000 (5%)]	Loss: 0.014051,	Sparsity: 98.41%
# Train Epoch: 2 [4800/60000 (8%)]	Loss: 0.014630,	Sparsity: 98.43%
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.005609,	Sparsity: 98.45%
# Train Epoch: 2 [8000/60000 (13%)]	Loss: 0.033307,	Sparsity: 98.46%
# Train Epoch: 2 [9600/60000 (16%)]	Loss: 0.004107,	Sparsity: 98.47%
# Train Epoch: 2 [11200/60000 (19%)]	Loss: 0.014806,	Sparsity: 98.49%
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.025021,	Sparsity: 98.50%
# Train Epoch: 2 [14400/60000 (24%)]	Loss: 0.065382,	Sparsity: 98.51%
#
# Test set: Average loss: 0.0171, Accuracy: 9952/10000 (100%), Sparsity: 98.52%
#
# Train Epoch: 2 [16000/60000 (27%)]	Loss: 0.000902,	Sparsity: 98.56%
# Train Epoch: 2 [17600/60000 (29%)]	Loss: 0.018008,	Sparsity: 98.59%
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.002272,	Sparsity: 98.60%
# Train Epoch: 2 [20800/60000 (35%)]	Loss: 0.001139,	Sparsity: 98.60%
# Train Epoch: 2 [22400/60000 (37%)]	Loss: 0.001212,	Sparsity: 98.61%
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.000779,	Sparsity: 98.61%
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.007934,	Sparsity: 98.61%
# Train Epoch: 2 [27200/60000 (45%)]	Loss: 0.177116,	Sparsity: 98.61%
# Train Epoch: 2 [28800/60000 (48%)]	Loss: 0.001747,	Sparsity: 98.62%
#
# Test set: Average loss: 0.0191, Accuracy: 9938/10000 (99%), Sparsity: 98.62%
#
# Train Epoch: 2 [30400/60000 (51%)]	Loss: 0.001908,	Sparsity: 98.62%
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.014499,	Sparsity: 98.62%
# Train Epoch: 2 [33600/60000 (56%)]	Loss: 0.133078,	Sparsity: 98.62%
# Train Epoch: 2 [35200/60000 (59%)]	Loss: 0.000945,	Sparsity: 98.62%
# Train Epoch: 2 [36800/60000 (61%)]	Loss: 0.005231,	Sparsity: 98.63%
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.000553,	Sparsity: 98.63%
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.030531,	Sparsity: 98.63%
# Train Epoch: 2 [41600/60000 (69%)]	Loss: 0.001694,	Sparsity: 98.63%
# Train Epoch: 2 [43200/60000 (72%)]	Loss: 0.002817,	Sparsity: 98.63%
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.016231,	Sparsity: 98.63%
#
# Test set: Average loss: 0.0206, Accuracy: 9934/10000 (99%), Sparsity: 98.63%
#
# Train Epoch: 2 [46400/60000 (77%)]	Loss: 0.006557,	Sparsity: 98.64%
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.003787,	Sparsity: 98.64%
# Train Epoch: 2 [49600/60000 (83%)]	Loss: 0.000769,	Sparsity: 98.64%
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.073558,	Sparsity: 98.64%
# Train Epoch: 2 [52800/60000 (88%)]	Loss: 0.002311,	Sparsity: 98.65%
# Train Epoch: 2 [54400/60000 (91%)]	Loss: 0.002625,	Sparsity: 98.65%
# Train Epoch: 2 [56000/60000 (93%)]	Loss: 0.107190,	Sparsity: 98.65%
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.000968,	Sparsity: 98.65%
# Train Epoch: 2 [59200/60000 (99%)]	Loss: 0.004158,	Sparsity: 98.66%
#
# Test set: Average loss: 0.0167, Accuracy: 9944/10000 (99%), Sparsity: 98.66%
#
# CPU times: user 8h 15min 50s, sys: 4h 43min 10s, total: 12h 59min
# Wall time: 9h 49min 11s

# %%
plot_stats(optimizer, data, num_dims=4)

# %%
### SAVE ###
# data_resnet = deepcopy(data)
# model_state_dict_resnet = deepcopy(model.state_dict())
# optimizer_state_dict_resnet = deepcopy(optimizer.state_dict())

### LOAD ###
# data = deepcopy(data_resnet)
# model.load_state_dict(model_state_dict_resnet)
# optimizer.load_state_dict(optimizer_state_dict_resnet)

# %% [markdown]
# # Experiment 4 (ViT)

# %%
args.experiment = "vit"
args.lr = 1e-3

rho = 0.1  # relative to lr
decay_rate = 0.1  # relative to lr
prune_threshold = 2**-8
decay_type = "l1"

optim_args = dict(lr=args.lr, rho=rho, scaled_max="adam", sam_ord=2, #amsgrad=True,
                  decay_type=decay_type, decay_rate=decay_rate, prune_threshold=prune_threshold)

model, optimizer, loss_fn, train_loader, test_loader, device = init_experiment(args, Optimizer=SADAM, **optim_args)

data = []
model_state_dict0 = deepcopy(model.state_dict())
optimizer_state_dict0 = deepcopy(optimizer.state_dict())
# Out:
# Using MPS
# Initializing model with random seed 0.
# Setting random seed to 0.
# Setting random seed to 0.
# Model has 3452554 parameters

# %%
# %%time
### Run ###
for epoch in range(1, 1 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 2.5278, Accuracy: 1012/10000 (10%), Sparsity: 0.12%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 2.637979,	Sparsity: 5.72%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.902878,	Sparsity: 11.04%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.528424,	Sparsity: 13.62%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.345912,	Sparsity: 15.62%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.179577,	Sparsity: 17.30%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.352705,	Sparsity: 18.98%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.308087,	Sparsity: 20.48%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.191312,	Sparsity: 22.05%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.284910,	Sparsity: 23.36%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.285617,	Sparsity: 24.44%
#
# Test set: Average loss: 0.2424, Accuracy: 9271/10000 (93%), Sparsity: 24.90%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.196349,	Sparsity: 25.63%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.259566,	Sparsity: 26.77%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.039964,	Sparsity: 27.82%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.242377,	Sparsity: 28.70%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.043074,	Sparsity: 29.62%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.184895,	Sparsity: 30.49%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.367725,	Sparsity: 31.33%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.535870,	Sparsity: 32.24%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.116427,	Sparsity: 33.07%
#
# Test set: Average loss: 0.1784, Accuracy: 9481/10000 (95%), Sparsity: 33.72%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.458933,	Sparsity: 33.93%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.213070,	Sparsity: 34.76%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:3
#
# Cell In[876], line 21, in train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch, log_interval, test_interval, get_gradnorm)
#      18     loss.backward()
#      19     return loss
# ---> 21 loss = optimizer.step(closure)
#      22 # Logging
#      23 if batch_idx % log_interval == 0:
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/optim/optimizer.py:280, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     276         else:
#     277             raise RuntimeError(f"{func} must return None or a tuple of (new_args, new_kwargs),"
#     278                                f"but got {result}.")
# --> 280 out = func(*args, **kwargs)
#     281 self._optimizer_step_code()
#     283 # call optimizer step post hooks
#
# Cell In[1197], line 73, in MaskedOptimizer.step(self, closure)
#      71 if self.use_masked_closure:
#      72     closure = self.masked_closure(closure)
# ---> 73 loss = super().step(closure)  # assuming first-order step
#      74 self.prune_smaller_than()
#      75 self.mask_params()
#
# File ~/opt/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# Cell In[1196], line 62, in DecoupledDecay.step(self, closure)
#      60 @torch.no_grad()
#      61 def step(self, closure):
# ---> 62     self._store_decay()
#      63     loss = super().step(closure)
#      64     self._apply_decay()
#
# Cell In[1196], line 19, in DecoupledDecay._store_decay(self)
#      17 for p in group['params']:
#      18     if self.decay_type == "l1":
# ---> 19         decay = torch.sign(p).clone()
#      21     elif self.decay_type == "hinge":
#      22         if "exp_avg_sq" in self.state[p]:
#
# KeyboardInterrupt:

# %%
# %%time
### Run ###
for epoch in range(1, 2 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 0.1947, Accuracy: 9423/10000 (94%), Sparsity: 57.47%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.238837,	Sparsity: 57.49%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.061282,	Sparsity: 58.54%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.049412,	Sparsity: 59.56%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.127072,	Sparsity: 60.55%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.159492,	Sparsity: 61.53%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.363166,	Sparsity: 62.48%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.182474,	Sparsity: 63.44%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.090924,	Sparsity: 64.36%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.355934,	Sparsity: 65.22%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.065352,	Sparsity: 66.08%
#
# Test set: Average loss: 0.1503, Accuracy: 9557/10000 (96%), Sparsity: 66.39%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.138064,	Sparsity: 66.92%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.046542,	Sparsity: 67.71%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.047767,	Sparsity: 68.51%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.044686,	Sparsity: 69.28%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.170520,	Sparsity: 70.03%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.214206,	Sparsity: 70.75%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.046871,	Sparsity: 71.43%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.194885,	Sparsity: 72.11%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.167584,	Sparsity: 72.77%
#
# Test set: Average loss: 0.1479, Accuracy: 9535/10000 (95%), Sparsity: 73.22%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.280659,	Sparsity: 73.38%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.016947,	Sparsity: 73.99%
# Train Epoch: 1 [33600/60000 (56%)]	Loss: 0.065738,	Sparsity: 74.56%
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.114288,	Sparsity: 75.11%
# Train Epoch: 1 [36800/60000 (61%)]	Loss: 0.193978,	Sparsity: 75.64%
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.042972,	Sparsity: 76.16%
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.028413,	Sparsity: 76.68%
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.033579,	Sparsity: 77.16%
# Train Epoch: 1 [43200/60000 (72%)]	Loss: 0.019790,	Sparsity: 77.62%
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.082643,	Sparsity: 78.07%
#
# Test set: Average loss: 0.1273, Accuracy: 9605/10000 (96%), Sparsity: 78.12%
#
# Train Epoch: 1 [46400/60000 (77%)]	Loss: 0.087310,	Sparsity: 78.50%
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.015555,	Sparsity: 78.93%
# Train Epoch: 1 [49600/60000 (83%)]	Loss: 0.109844,	Sparsity: 79.35%
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.099350,	Sparsity: 79.75%
# Train Epoch: 1 [52800/60000 (88%)]	Loss: 0.011053,	Sparsity: 80.13%
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.048688,	Sparsity: 80.50%
# Train Epoch: 1 [56000/60000 (93%)]	Loss: 0.032797,	Sparsity: 80.86%
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.121141,	Sparsity: 81.20%
# Train Epoch: 1 [59200/60000 (99%)]	Loss: 0.245102,	Sparsity: 81.52%
#
# Test set: Average loss: 0.1196, Accuracy: 9635/10000 (96%), Sparsity: 81.68%
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.179768,	Sparsity: 81.68%
# Train Epoch: 2 [1600/60000 (3%)]	Loss: 0.149903,	Sparsity: 81.99%
# Train Epoch: 2 [3200/60000 (5%)]	Loss: 0.157982,	Sparsity: 82.29%
# Train Epoch: 2 [4800/60000 (8%)]	Loss: 0.053749,	Sparsity: 82.59%
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.132826,	Sparsity: 82.87%
# Train Epoch: 2 [8000/60000 (13%)]	Loss: 0.081906,	Sparsity: 83.14%
# Train Epoch: 2 [9600/60000 (16%)]	Loss: 0.132617,	Sparsity: 83.41%
# Train Epoch: 2 [11200/60000 (19%)]	Loss: 0.059101,	Sparsity: 83.67%
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.163411,	Sparsity: 83.92%
# Train Epoch: 2 [14400/60000 (24%)]	Loss: 0.054335,	Sparsity: 84.17%
#
# Test set: Average loss: 0.1022, Accuracy: 9694/10000 (97%), Sparsity: 84.25%
#
# Train Epoch: 2 [16000/60000 (27%)]	Loss: 0.211882,	Sparsity: 84.41%
# Train Epoch: 2 [17600/60000 (29%)]	Loss: 0.024995,	Sparsity: 84.64%
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.079326,	Sparsity: 84.86%
# Train Epoch: 2 [20800/60000 (35%)]	Loss: 0.026241,	Sparsity: 85.07%
# Train Epoch: 2 [22400/60000 (37%)]	Loss: 0.017948,	Sparsity: 85.30%
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.091697,	Sparsity: 85.51%
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.070998,	Sparsity: 85.71%
# Train Epoch: 2 [27200/60000 (45%)]	Loss: 0.041260,	Sparsity: 85.92%
# Train Epoch: 2 [28800/60000 (48%)]	Loss: 0.093744,	Sparsity: 86.10%
#
# Test set: Average loss: 0.1029, Accuracy: 9681/10000 (97%), Sparsity: 86.25%
#
# Train Epoch: 2 [30400/60000 (51%)]	Loss: 0.098284,	Sparsity: 86.29%
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.024390,	Sparsity: 86.47%
# Train Epoch: 2 [33600/60000 (56%)]	Loss: 0.051533,	Sparsity: 86.65%
# Train Epoch: 2 [35200/60000 (59%)]	Loss: 0.034662,	Sparsity: 86.83%
# Train Epoch: 2 [36800/60000 (61%)]	Loss: 0.071814,	Sparsity: 87.00%
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.129610,	Sparsity: 87.17%
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.039563,	Sparsity: 87.33%
# Train Epoch: 2 [41600/60000 (69%)]	Loss: 0.088476,	Sparsity: 87.49%
# Train Epoch: 2 [43200/60000 (72%)]	Loss: 0.016531,	Sparsity: 87.64%
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.114458,	Sparsity: 87.79%
#
# Test set: Average loss: 0.1074, Accuracy: 9637/10000 (96%), Sparsity: 87.81%
#
# Train Epoch: 2 [46400/60000 (77%)]	Loss: 0.028577,	Sparsity: 87.94%
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.013371,	Sparsity: 88.08%
# Train Epoch: 2 [49600/60000 (83%)]	Loss: 0.053790,	Sparsity: 88.21%
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.031379,	Sparsity: 88.34%
# Train Epoch: 2 [52800/60000 (88%)]	Loss: 0.030170,	Sparsity: 88.48%
# Train Epoch: 2 [54400/60000 (91%)]	Loss: 0.038026,	Sparsity: 88.60%
# Train Epoch: 2 [56000/60000 (93%)]	Loss: 0.009544,	Sparsity: 88.73%
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.159742,	Sparsity: 88.85%
# Train Epoch: 2 [59200/60000 (99%)]	Loss: 0.017132,	Sparsity: 88.97%
#
# Test set: Average loss: 0.0781, Accuracy: 9742/10000 (97%), Sparsity: 89.03%
#
# CPU times: user 2h 18min 58s, sys: 2h 34s, total: 4h 19min 33s
# Wall time: 50min 41s

# %%
# %%time
### Run ###
for epoch in range(1, 2 + 1):
    results = train(model, optimizer, loss_fn, train_loader, test_loader, device, epoch)
    data += results
# Out:
# Test set: Average loss: 0.0781, Accuracy: 9742/10000 (97%), Sparsity: 89.03%
#
# Train Epoch: 1 [0/60000 (0%)]	Loss: 0.038345,	Sparsity: 89.03%
# Train Epoch: 1 [1600/60000 (3%)]	Loss: 0.044048,	Sparsity: 89.15%
# Train Epoch: 1 [3200/60000 (5%)]	Loss: 0.087132,	Sparsity: 89.26%
# Train Epoch: 1 [4800/60000 (8%)]	Loss: 0.027747,	Sparsity: 89.38%
# Train Epoch: 1 [6400/60000 (11%)]	Loss: 0.013837,	Sparsity: 89.49%
# Train Epoch: 1 [8000/60000 (13%)]	Loss: 0.089488,	Sparsity: 89.59%
# Train Epoch: 1 [9600/60000 (16%)]	Loss: 0.084811,	Sparsity: 89.70%
# Train Epoch: 1 [11200/60000 (19%)]	Loss: 0.062818,	Sparsity: 89.79%
# Train Epoch: 1 [12800/60000 (21%)]	Loss: 0.116254,	Sparsity: 89.89%
# Train Epoch: 1 [14400/60000 (24%)]	Loss: 0.031695,	Sparsity: 89.98%
#
# Test set: Average loss: 0.0938, Accuracy: 9711/10000 (97%), Sparsity: 90.02%
#
# Train Epoch: 1 [16000/60000 (27%)]	Loss: 0.025641,	Sparsity: 90.08%
# Train Epoch: 1 [17600/60000 (29%)]	Loss: 0.015586,	Sparsity: 90.17%
# Train Epoch: 1 [19200/60000 (32%)]	Loss: 0.075770,	Sparsity: 90.26%
# Train Epoch: 1 [20800/60000 (35%)]	Loss: 0.085205,	Sparsity: 90.35%
# Train Epoch: 1 [22400/60000 (37%)]	Loss: 0.068153,	Sparsity: 90.43%
# Train Epoch: 1 [24000/60000 (40%)]	Loss: 0.041074,	Sparsity: 90.51%
# Train Epoch: 1 [25600/60000 (43%)]	Loss: 0.010519,	Sparsity: 90.60%
# Train Epoch: 1 [27200/60000 (45%)]	Loss: 0.030129,	Sparsity: 90.68%
# Train Epoch: 1 [28800/60000 (48%)]	Loss: 0.114415,	Sparsity: 90.76%
#
# Test set: Average loss: 0.1052, Accuracy: 9676/10000 (97%), Sparsity: 90.82%
#
# Train Epoch: 1 [30400/60000 (51%)]	Loss: 0.141987,	Sparsity: 90.84%
# Train Epoch: 1 [32000/60000 (53%)]	Loss: 0.313619,	Sparsity: 90.91%
# Train Epoch: 1 [33600/60000 (56%)]	Loss: 0.013000,	Sparsity: 90.99%
# Train Epoch: 1 [35200/60000 (59%)]	Loss: 0.019296,	Sparsity: 91.06%
# Train Epoch: 1 [36800/60000 (61%)]	Loss: 0.044612,	Sparsity: 91.13%
# Train Epoch: 1 [38400/60000 (64%)]	Loss: 0.213886,	Sparsity: 91.20%
# Train Epoch: 1 [40000/60000 (67%)]	Loss: 0.013408,	Sparsity: 91.26%
# Train Epoch: 1 [41600/60000 (69%)]	Loss: 0.123145,	Sparsity: 91.34%
# Train Epoch: 1 [43200/60000 (72%)]	Loss: 0.080467,	Sparsity: 91.40%
# Train Epoch: 1 [44800/60000 (75%)]	Loss: 0.190008,	Sparsity: 91.47%
#
# Test set: Average loss: 0.0810, Accuracy: 9745/10000 (97%), Sparsity: 91.48%
#
# Train Epoch: 1 [46400/60000 (77%)]	Loss: 0.075670,	Sparsity: 91.53%
# Train Epoch: 1 [48000/60000 (80%)]	Loss: 0.019081,	Sparsity: 91.60%
# Train Epoch: 1 [49600/60000 (83%)]	Loss: 0.034586,	Sparsity: 91.67%
# Train Epoch: 1 [51200/60000 (85%)]	Loss: 0.041675,	Sparsity: 91.73%
# Train Epoch: 1 [52800/60000 (88%)]	Loss: 0.018735,	Sparsity: 91.78%
# Train Epoch: 1 [54400/60000 (91%)]	Loss: 0.021567,	Sparsity: 91.84%
# Train Epoch: 1 [56000/60000 (93%)]	Loss: 0.115127,	Sparsity: 91.90%
# Train Epoch: 1 [57600/60000 (96%)]	Loss: 0.011305,	Sparsity: 91.96%
# Train Epoch: 1 [59200/60000 (99%)]	Loss: 0.421337,	Sparsity: 92.02%
#
# Test set: Average loss: 0.0787, Accuracy: 9768/10000 (98%), Sparsity: 92.04%
#
# Train Epoch: 2 [0/60000 (0%)]	Loss: 0.046203,	Sparsity: 92.04%
# Train Epoch: 2 [1600/60000 (3%)]	Loss: 0.010815,	Sparsity: 92.10%
# Train Epoch: 2 [3200/60000 (5%)]	Loss: 0.020244,	Sparsity: 92.16%
# Train Epoch: 2 [4800/60000 (8%)]	Loss: 0.063620,	Sparsity: 92.21%
# Train Epoch: 2 [6400/60000 (11%)]	Loss: 0.099181,	Sparsity: 92.27%
# Train Epoch: 2 [8000/60000 (13%)]	Loss: 0.142487,	Sparsity: 92.32%
# Train Epoch: 2 [9600/60000 (16%)]	Loss: 0.143563,	Sparsity: 92.37%
# Train Epoch: 2 [11200/60000 (19%)]	Loss: 0.014370,	Sparsity: 92.42%
# Train Epoch: 2 [12800/60000 (21%)]	Loss: 0.040768,	Sparsity: 92.47%
# Train Epoch: 2 [14400/60000 (24%)]	Loss: 0.236044,	Sparsity: 92.52%
#
# Test set: Average loss: 0.0732, Accuracy: 9786/10000 (98%), Sparsity: 92.53%
#
# Train Epoch: 2 [16000/60000 (27%)]	Loss: 0.090485,	Sparsity: 92.56%
# Train Epoch: 2 [17600/60000 (29%)]	Loss: 0.153325,	Sparsity: 92.61%
# Train Epoch: 2 [19200/60000 (32%)]	Loss: 0.081495,	Sparsity: 92.66%
# Train Epoch: 2 [20800/60000 (35%)]	Loss: 0.036745,	Sparsity: 92.70%
# Train Epoch: 2 [22400/60000 (37%)]	Loss: 0.102782,	Sparsity: 92.75%
# Train Epoch: 2 [24000/60000 (40%)]	Loss: 0.102037,	Sparsity: 92.79%
# Train Epoch: 2 [25600/60000 (43%)]	Loss: 0.119045,	Sparsity: 92.84%
# Train Epoch: 2 [27200/60000 (45%)]	Loss: 0.043645,	Sparsity: 92.88%
# Train Epoch: 2 [28800/60000 (48%)]	Loss: 0.036820,	Sparsity: 92.92%
#
# Test set: Average loss: 0.0799, Accuracy: 9747/10000 (97%), Sparsity: 92.95%
#
# Train Epoch: 2 [30400/60000 (51%)]	Loss: 0.044008,	Sparsity: 92.96%
# Train Epoch: 2 [32000/60000 (53%)]	Loss: 0.008095,	Sparsity: 93.01%
# Train Epoch: 2 [33600/60000 (56%)]	Loss: 0.079170,	Sparsity: 93.05%
# Train Epoch: 2 [35200/60000 (59%)]	Loss: 0.043019,	Sparsity: 93.09%
# Train Epoch: 2 [36800/60000 (61%)]	Loss: 0.042535,	Sparsity: 93.14%
# Train Epoch: 2 [38400/60000 (64%)]	Loss: 0.146052,	Sparsity: 93.18%
# Train Epoch: 2 [40000/60000 (67%)]	Loss: 0.047050,	Sparsity: 93.22%
# Train Epoch: 2 [41600/60000 (69%)]	Loss: 0.031371,	Sparsity: 93.26%
# Train Epoch: 2 [43200/60000 (72%)]	Loss: 0.366397,	Sparsity: 93.30%
# Train Epoch: 2 [44800/60000 (75%)]	Loss: 0.113604,	Sparsity: 93.33%
#
# Test set: Average loss: 0.0724, Accuracy: 9794/10000 (98%), Sparsity: 93.34%
#
# Train Epoch: 2 [46400/60000 (77%)]	Loss: 0.015960,	Sparsity: 93.37%
# Train Epoch: 2 [48000/60000 (80%)]	Loss: 0.160737,	Sparsity: 93.41%
# Train Epoch: 2 [49600/60000 (83%)]	Loss: 0.098563,	Sparsity: 93.44%
# Train Epoch: 2 [51200/60000 (85%)]	Loss: 0.055171,	Sparsity: 93.48%
# Train Epoch: 2 [52800/60000 (88%)]	Loss: 0.223382,	Sparsity: 93.52%
# Train Epoch: 2 [54400/60000 (91%)]	Loss: 0.084431,	Sparsity: 93.56%
# Train Epoch: 2 [56000/60000 (93%)]	Loss: 0.009611,	Sparsity: 93.60%
# Train Epoch: 2 [57600/60000 (96%)]	Loss: 0.040854,	Sparsity: 93.63%
# Train Epoch: 2 [59200/60000 (99%)]	Loss: 0.050657,	Sparsity: 93.67%
#
# Test set: Average loss: 0.0815, Accuracy: 9745/10000 (97%), Sparsity: 93.68%
#
# CPU times: user 2h 21min 46s, sys: 1h 58min 7s, total: 4h 19min 54s
# Wall time: 55min 59s

# %%
plot_stats(optimizer, data)

# %%
### SAVE ###
# data_vit = deepcopy(data)
# model_state_dict_vit = deepcopy(model.state_dict())
# optimizer_state_dict_vit = deepcopy(optimizer.state_dict())

### LOAD ###
# data = deepcopy(data_vit)
# model.load_state_dict(model_state_dict_vit)
# optimizer.load_state_dict(optimizer_state_dict_vit)
